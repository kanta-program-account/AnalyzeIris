# %%
from AnalyzeIris import AnalyzeIris

# %%
# Practice1
iris = AnalyzeIris()

# %%
# iris.Get()

# %%
# iris.PairPlot()

# %%
# iris.PairPlot('prism')

# %%
# iris.PairPlot('brg')

# %%
# Practice2
# iris.AllSupervised(n_neighbors=4)

# %%
# iris.GetSupervised()

# %%
# df_score = iris.GetSupervised().describe()
# df_score

# %%
# best_method, best_score = iris.BestSupervised()
# print("BestMethod is ", best_method, " : ", "{0:0.4f}".format(best_score))

# %%
# iris.PlotFeatureImportancesAll()

# %%
# iris.VisualizeDecisionTree()

# %%
# Practice3
iris.PlotScaledData()
# Out:
# Original         : test score: 1.000     train score: 0.967
# MinMaxScaler     : test score: 0.900     train score: 0.925
# StandardScaler   : test score: 0.967     train score: 0.950
# RobustScaler     : test score: 0.967     train score: 0.942
# Normalizer       : test score: 0.900     train score: 0.917
# ...
# Original         : test score: 0.833     train score: 0.975
# MinMaxScaler     : test score: 0.900     train score: 0.958
# StandardScaler   : test score: 0.867     train score: 0.958
# RobustScaler     : test score: 0.900     train score: 0.950
# Normalizer       : test score: 0.833     train score: 0.917
# ...
# Original         : test score: 1.000     train score: 0.967
# MinMaxScaler     : test score: 0.867     train score: 0.925
# StandardScaler   : test score: 0.900     train score: 0.950
# RobustScaler     : test score: 0.900     train score: 0.942
# Normalizer       : test score: 0.900     train score: 0.900
# ...
# Original         : test score: 0.967     train score: 0.975
# ...

# %%
iris.PlotFeatureHistgram()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 iris.PlotFeatureHistgram()
#
# File c:\Users\kyabe\OneDrive\デスクトップ\Work\WALC\iris\AnalyzeIris.py:361, in AnalyzeIris.PlotFeatureHistgram(self)
#     358 """Show histgrams of the frequency for each feature in various range.
#     359 """
#     360 X, y = self.X, self.y
# --> 361 feature_names = self.iris_dataset.feature_names
#     362 target_names = self.iris_dataset.target_names  # クラス名を修正
#     363 colors = ['blue', 'red', 'green']  # クラスごとの色を指定
#
# AttributeError: 'AnalyzeIris' object has no attribute 'iris_dataset'

# %%
X_scaled, df_pca, X_pca = iris.PlotPCA(n_components=2)

# %%
X_scaled

# %%
df_pca

# %%
X_pca.components_

# %%
X_scaled, df_nmf, X_nmf = iris.PlotNMF(n_components=2)

# %%
iris.PlotTSNE()

# %%
iris.PlotKMeans() # X, yがshuffleされなければAnalyzeirisと同じ結果

# %%
iris.PlotDendrogram()

# %%
iris.PlotDendrogram(truncate=True)

# %%
iris.PlotDBSCAN()

# %%
iris.PlotDBSCAN(scaling=True, eps=0.5, min_samples=5)

# %%
#最終課題
# k-means
# 特徴:クラスタ重心(クラスタセンタ)を見つけるアルゴリズム。
# メリット:クラスタが単純の形の場合上手く機能する。ベクトル量子化の考え方に基づき、クラスタセンタという各データポイントの重心を画像の成分(PCAやNMFの複数成分に相当)として使用できる為、PCAやNMFより強力な成分を見つけることが出来る。理解しやすく、高速。
# デメリット:重心だけでクラスタが定義される為、クラスタが複雑な形の場合は上手く機能しない。初期化が乱数で行なわれるため、再現性は比較的低い。探すクラスタの数をユーザーが指定しなければならない。

# dendrogram
# 特徴:データ点の近い順にクラスタリングされていくアルゴリズム。凝集型クラスタリングを階層に可視化したもの(階層型クラスタリング)。"近さ"の基準は ward, average, complete など複数種類ある。
# メリット:クラスタリングのプロセスを可視化できる。
# デメリット:2次元でしか使えない。クラスタが複雑な形の場合は上手く機能しない。

# DBSCAN
# 特徴:データポイントの密度に基づきクラスタリングを行うアルゴリズム。
# メリット:min_samples, epsパラメータにより、大小様々なデータセットにも適用可能。
# デメリット:処理が遅い。
